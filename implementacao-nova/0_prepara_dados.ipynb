# %%
import tarfile 
  
file = tarfile.open('../dados/spotify_million_playlist_dataset_challenge.tar.xz') 
file.extractall('../dados/') 
  
file.close()

# %%
from json import load

with open("../dados/spotify_million_playlist_dataset_challenge/challenge_set.json", 'r') as _file:
    dataset_json = load(_file)

dataset_playlists = dataset_json['playlists']

# %%
import pandas as pd

pd.DataFrame(dataset_playlists)
# Out:
#                   name  num_holdouts      pid  num_tracks  \
# 0     spanish playlist            11  1000002          11
# 1              Groovin            48  1000003          48
# 2               uplift            40  1000004          40
# 3                 WUBZ            27  1000006          27
# 4                  new            41  1000007          41
# ...                ...           ...      ...         ...
# 9995     Playlist 2015            20  1006767          21
# 9996           Workout            24  1006771          25
# 9997             Girlz            16  1006773          17
# 9998    let's get lost            35  1006775          36
# 9999              Mama            28  1006778          29
#
#                                                  tracks  num_samples
# 0                                                    []            0
# 1                                                    []            0
# ...
